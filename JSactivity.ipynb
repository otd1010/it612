# %% [markdown]
# <a href="https://colab.research.google.com/github/otd1010/it612/blob/main/JSactivity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
#
# const addTax = (price, rate) => {
#   return price + (price * rate)
# }
#
# const createBurner(secret, limit) {
#   let count = 0;
#   return function() {
#     if(count<limit) {
#       count++;
#       return secret;
#     }
#   }
# }
